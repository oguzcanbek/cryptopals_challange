# %%
import os
import sys
module_path = os.path.abspath(os.path.join('..\..'))
if module_path not in sys.path:
    sys.path.append(module_path)
    
import binascii
import math
import numpy as np
import importlib
print(module_path)

from libraries import encryption_standards as es
from libraries import crypto
from libraries import numeral

importlib.reload(es)
importlib.reload(crypto)
importlib.reload(numeral)
# Out:
# C:\Users\oguz.canbek\Desktop\cryptopals_challenge
# <module 'libraries.numeral' from 'C:\\Users\\oguz.canbek\\Desktop\\cryptopals_challenge\\libraries\\numeral.py'>

# %%
data_path = "C:\\Users\\oguz.canbek\\Desktop\\cryptopals_challenge\\challanges\\set_1\\challenge_7.txt"
data = np.loadtxt(data_path, dtype='str')

data_str = ""

for row in data:
    data_str += row
    
print(len(data_str))

data_str
# Out:
# 3840
# '...'

# %%
deneme = es.Encrypto(ciphertext=data_str, base=64)

deneme.Base16()
deneme.Base64()

# len(deneme.value)

for idx, letter in enumerate(data_str):
#     print(letter , ":", deneme.value[idx])
    a = 1
    
print(deneme.value == data_str)
print(len(deneme.value))

es.Encrypto.
# Out:
# True
# 3840

# %%
importlib.reload(crypto)

ch_7_obj = es.Encrypto(ciphertext=data_str, base=64)
ch_7_obj.Base2()

ch_7_key = crypto.Crypto(plaintext="YELLOW SUBMARINE")
print(ch_7_key.value)

# ch_7_key.Base2()

   
# bits_to_add = blocksize - remainder

# for i in range(bits_to_add):
#     ch_7_obj.value += "0"

blocksize = 128
number_of_blocks = int(len(ch_7_obj.value)/blocksize)

blocks = [crypto.Crypto(ciphertext=ch_7_obj.value[i*blocksize:(i+1)*blocksize], base=2) for i in range(number_of_blocks)]

for block in blocks:
    a = block.decodeRepeatingByteXOR(ch_7_key)
#     print(ch_7_key.value)
    print(a)
# Out:
# 59454c4c4f57205355424d4152494e45
# PW|æicèªÄd)
# nòa@»g®E«u
# tôhÏ) Au
# Tüv'ÀãMª}à«6
# Ô¹2Ò-C"^rÍè
# Ô­ËêÇî1;bßF
# ¿Àáï×b±¶,%¢cj
# ¦ÐpªqÐ{¸"!ÍÜk
# ùÝJVÆZ8çÈÐm-ÿñ
# QUº$³c{Þ.Ë¹"K@
# æ-TÆ·Ô¿QS:qiO
# ÃëváðB (¦"a\¸s
# ÏÕIéû\®<óÞ`
# û'5çEówÔ	:~Æ¤Ï­
# ¦cTë/o¼-LÈ
# 4Ëî`®íg.¯Eå
# OØ÷ý\{\ÖGYr
# *j è¤Ö%>ûm¨Þ
# ÷­J cOôÄ F«Ê
# òm©¶3ók$·%X
# ¶§ââUsd ñ!ì
# #º}gÙöÐ®&rÃÇÀ
# )"~[õLIä|Ì+
# U¥ÜX*>w3ÔéD¶
# g¾6kdù@Gy¼ ã
# +B)}çåÈN²É{ìû
# ýx¥GðÈ÷4%A
# Öy°ð·5(ê]L±yrº
# R1¶Açf#'Æx7Fú
# 9-Ûû7@íDR·^M
# pOÀæês2´L>S5!
# p²wRñ$´Z	±à²ß
# /fzFk¼|
# îMOìfOOð<XÉÌ
# Ú²GdQ4qg÷·kþàk´
# ßñ%òF(_B_
# ©f¯
# 5sÃ¼@b
# TéÜÑê{kÍ{»
# ÖÊDº*§Ã2NVÊä
# ;«ÒõÆÁ¬)¸æÎÃÔ
# º«ÍcÂJpÙáµR·
# Á2[&<ôÊA2ë_b¸
# Toðû.	¨kq¨/ùß4
# Ö9±o»TBwýW½Ëý
# ¹:¦ôKhaÁamñZ
# ´p\>¡ÚòIæò­Ó
# 
# ®Ì6µRý´4¾mqÈ
# ±Q@{ñHW(­k#ÛÛ
# Se r¼+ú°6p
# Ê¿`þmvõ,Ö&
# ·ËBO
# íVÔª^Îm
# >
# >[ùDùFSéÈïo6
# Oq½Þó$U+}gs§Ô>
# ;ÎzÈ	÷:lÏÀ>Çm
# #³ØN­pF
# ¤âyM(ÂP\:X(
# ...

# %%
data_path_2 = "C:\\Users\\oguz.canbek\\Desktop\\ort.txt"
data_2 = np.loadtxt(data_path, dtype='str')

i=0
total=0
for num in data_2:
    a = num.replace(',', '.')
#     print(a)
    total += float(a)
    i +=1
    
total / i
# Out:
# 1.6376119402985072
