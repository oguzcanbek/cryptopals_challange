# %%
import os
import sys
module_path = os.path.abspath(os.path.join('..\..'))
if module_path not in sys.path:
    sys.path.append(module_path)
    
import binascii
import math
import numpy as np
import importlib
print(module_path)

from libraries import crypto
from libraries import numeral

importlib.reload(crypto)
importlib.reload(numeral)
# Out:
# C:\Users\Oguz\Desktop\Cryptopals Challange
# <module 'libraries.numeral' from 'C:\\Users\\Oguz\\Desktop\\Cryptopals Challange\\libraries\\numeral.py'>

# %% [markdown]
# <p style="color:royalblue; font-size:18px;">
#     <b>
#         Loading the Challange 6 Data
#     </b>
# </p>

# %%
challange_data_addr = "C:\\Users\\Oguz\\Desktop\\Cryptopals Challange\\challanges\\set_1\\challange_6.txt"
data = np.loadtxt(challange_data_addr, dtype='str')
print("Data length is", len(data))
first_string = data[-1]
first_string_len = len(first_string)
print("String: ", first_string)
print("Length: ", first_string_len)
first_string[-1]


data_str = "" 
lenn = 0
for elem in data:
    dum_len = len(elem)
    lenn += dum_len
    data_str += elem
data_str = data_str[:-1]

print("str len:", len(data_str))
print("txt len:", lenn)

data_str
# Out:
# Data length is 64
# String:  Jk8DCkkcC3hFMQIEC0EbAVIqCFZBO1IdBgZUVA4QTgUWSR4QJwwRTWM=
# Length:  56
# str len: 3835
# txt len: 3836
# '...'

# %% [markdown]
# <p style="color:royalblue; font-size:18px;">
#     <b>
#         Finding the Hamming Distance
#     </b>
# </p>

# %%
test_plaintext = "this is a test"
test_key = "wokka wokka!!!"


distance_deneme = crypto.Crypto(plaintext=test_plaintext)

distance_deneme.findHammingDistance(test_key)
# Out:
# 0111011101101111011010110110101101100001001000000111011101101111011010110110101101100001001000010010000100100001
# 37

# %% [markdown]
# <p style="color:royalblue; font-size:18px;">
#     <b>
#         Finding the Keysize
#     </b>
# </p>
#
# For each KEYSIZE, take the first KEYSIZE worth of bytes, and the second KEYSIZE worth of bytes, and find the edit distance between them. Normalize this result by dividing by KEYSIZE.
#
# The KEYSIZE with the smallest normalized edit distance is probably the key. You could proceed perhaps with the smallest 2-3 KEYSIZE values. Or take 4 KEYSIZE blocks instead of 2 and average the distances.

# %%
distance_deneme.Base2()
test_bytes = distance_deneme.value
print(test_bytes)

keysize = 3


crypto.Crypto.findKeysizeScore(keysize, test_bytes)
# Out:
# 0111010001101000011010010111001100100000011010010111001100100000011000010010000001110100011001010111001101110100
# 4.666666666666667

# %% [markdown]
# <p style="color:royalblue; font-size:18px;">
#     <b>
#         Finding the Keysize for the Challange 6 Text
#     </b>
# </p>
#
# <p style="color:block; font-size:14px;">
#     <b>
#       <p> For each KEYSIZE, take the first KEYSIZE worth of bytes, and the second KEYSIZE worth of bytes, and find the edit distance between them. Normalize this result by dividing by KEYSIZE.
#       </p>
#       <p>The KEYSIZE with the smallest normalized edit distance is probably the key. You could proceed perhaps with the
#         smallest 2-3 KEYSIZE values. Or take 4 KEYSIZE blocks instead of 2 and average the distances.
#         </p>
#     </b>
# </p>

# %%
importlib.reload(crypto)
 

challange_6_numeral = numeral.Numeral(value=data_str, base=64)
challange_6_numeral.Base16()

challange_6 = crypto.Crypto(ciphertext = challange_6_numeral.value)

challange_6_scores = challange_6.findKeysize()
print(challange_6_scores)

N = 5
min_score_idx = np.array(challange_6_scores).argsort()[:N][::1]

# Add the index off (Keysize starts from 2)
min_score_idx += 2

print(min_score_idx)
print(len(challange_6_numeral.value))
# Out:
# [3.30542043 3.29548611 3.27569444 3.31631944 3.36944444 3.28120666
#  3.30277778 3.25277778 3.31041667 3.29007634 3.29548611 3.23007623
#  3.30790569 3.240625   3.24097222 3.2916955  3.27916667 3.32098338
#  3.24027778 3.2826087  3.22380291 3.30434783 3.31666667 3.25413793
#  3.25675676 3.29075805 3.32454924 2.8662069  3.26979167 3.29205689
#  3.27326389 3.25792011 3.27854671 3.2908778  3.24270833 3.29417879
#  3.23303324 3.27061677 3.24756944 3.2713844 ]
# [29 22 13 38 20]
# 5754

# %%
importlib.reload(numeral)


print(challange_6.base)

# challange_6.Base64()
challange_6.Base2()
# challange_6.Base10()
# challange_6.Base16()
# challange_6.Base64()
challange_6.value
# Out:
# 16
# '...'

# %% [markdown]
# <p style="color:royalblue; font-size:18px;">
#     <b>
#         Finding the Key
#     </b>
# </p>
#
# <p style="color:block; font-size:14px;">
#     <b>
#       <p> Now that you probably know the KEYSIZE: break the ciphertext into blocks of KEYSIZE length.</p>
#       <p>Now transpose the blocks: make a block that is the first byte of every block, and a block that is the second byte of every block, and so on. Solve each block as if it was single-character XOR. You already have code to do this.</p>
#     </b>
# </p>

# %%
# challange_6.Base2()
# print(challange_6.base)

keysize_cand = min_score_idx[0]
blocksize = keysize_cand * 8
bin_data = challange_6.value

# Add 0's to the and of the data so that it is evenly divisible to KEYSIZE
bin_data_size = len(bin_data)
# print(bin_data_size)
# remainder = bin_data_size % (blocksize)
# print(remainder)
# for i in range(abs(blocksize - remainder)):
#     bin_data += "0"
# bin_data_size = len(bin_data)
# print(bin_data_size)

# Create number of numerals to hold each block
numeral_objs = [numeral.Numeral(value="", base=2) for i in range(keysize_cand)]

# Break the ciphertext into blocks of KEYSIZE length.
block_no = int(bin_data_size / blocksize) + 1
print(block_no)
print("***")

block_list = []

# In the first loop divide the data into (Keysize*8) bits
for i in range(block_no):
    dummy_block = bin_data[(i*blocksize):(i+1)*blocksize]
    block_list.append(dummy_block)
#     print(len(dummy_block))
#     print("***")
    #In the second loop divide each block, and create a block of first, second, etc bytes
    
for keysize_block in block_list:
    print(len(keysize_block))
    for j in range(keysize_cand):
        dummy_chunk = keysize_block[(j*8):(j+1)*8]
        numeral_objs[j].value = numeral_objs[j].value + dummy_chunk


# Convert the numeral_objs to Base16
for i in range(keysize_cand):
    print(len(numeral_objs[i].value))
    numeral_objs[i].Base16()
    print((numeral_objs[i].value))
#     print(len(numeral_objs[i].value))


block_list[-1]
# Out:
# 100
# ***
# 232
# 232
# 232
# 232
# 232
# 232
# 232
# 232
# 232
# 232
# 232
# 232
# 232
# 232
# 232
# 232
# 232
# 232
# 232
# 232
# 232
# 232
# 232
# 232
# 232
# 232
# 232
# 232
# 232
# 232
# 232
# 232
# 232
# 232
# 232
# 232
# 232
# 232
# 232
# 232
# 232
# 232
# 232
# 232
# 232
# 232
# 232
# 232
# 232
# 232
# 232
# 232
# 232
# 232
# 232
# 232
# 232
# 232
# 232
# 232
# 232
# 232
# 232
# 232
# 232
# 232
# 232
# 232
# 232
# 232
# 232
# 232
# 232
# 232
# 232
# 232
# 232
# 232
# 232
# 232
# 232
# 232
# 232
# 232
# 232
# 232
# 232
# 232
# 232
# 232
# 232
# 232
# 232
# 232
# 232
# 232
# 232
# 232
# 232
# 48
# 800
# 1d373c3739743a3674263c745e3b37313a393b3e3522363a3b752420a5303c343a74363a73757431210d743d363bd518281414112414719c40341c5844082e150800150471706514140501102d0418184090355d00d8d828482910049815141440302e40
# 800
# 42000c264504010b0b10100c284204450b00090b16000b420b0a094548451c0c456f0e45260d1117114a0b45090bedecb0d9d4d0c9c8d0b4ccc4b5edd4981078f4c178f0d0c4d4d8dcd4d0e9d184c5f0d4e8810598d8d4b5f1d1b5f8ec78dc80c0e1219c
len(crypto_objs[0].value)

ch_6_key = ""
for i in range(keysize_cand):
    _, letter_k = crypto_objs[i].decipherSingleByteXOR(print_sln=True, N=1)
    ch_6_key += letter_k
    print("***")

print(ch_6_key)
# Out:
# Key:  T  / Solution:  Ichcm nb rh ocenmojavbno!ptñdh`n bn'! euY iboL|@@Ep@%È`H\zA\TAP%$1@@QUDyPLLÄaT|}DPÌA@@dz
# ***
# Key:  e  / Solution:  'eiC adnnuuiM'a nelnsen'nol - yi k Chtrt/n lnÕ¼±µ¬­µÑ©¡Ð±ýu¤µ¡±½¹±µ´á ±ä`ý½±Ð´Ð¹å¥Dù
# ***
# Key:  Q  / Solution:  NOOWWOzLDWWZV(?4F3FEBV)NOF-FBLVLNZEqaE}áEÙadEEyqE¡aA¡yAAuEEtq!EE!  EEíEPqyeQtEa
# ***
# Key:  m  / Solution:   ,eahltlt h  àCAàt 0mdp fIp-Fe)f  =nn  n7 90 ý)y4)!1%0uuqe%l5A) 0%00uu5-$9yu0@!l%©(
# ***
# Key:  U  / Solution:  ^O]TPWL{RHnT]öY]ESOOZ_TS[LSPHeXeE`t)e5|1aAeQYYeQt4a`Xdapèea#qa#EAu]T`\AeA` eaða=]`
# ***
# Key:  n  / Solution:  atyttealialoo dhoelTànaamta r teaeS  ertl)GaorWrVJ_f\Jj_^[_nJJN~JVJnzRâwâ~NN[VKn/Nãv/.Jrj~â
# ***
# Key:  a  / Solution:  cAh 'h çac.os t e  lhacI'yhn aicnradÊDa  moDm}Y}d}}XXLeXHH[huuema<ð\mIUh}éY½LH<XdñY±`YeAe}L
# ***
# Key:  t  / Solution:  k eisegszkd7sVhingsoene   rTogtct meB ciged e@PHqø=xpÙM0HppØpteITa0ØHpdL=p!d pMAppp¼p0e`p¼B %$- 0
# ***
# Key:  o  / Solution:  àr .0mi0yà ,eaa& etG d who 0ore twsnumtfe,, ;â?k;K?#â7ï?3#?o.#?n3j?c;c?'??>*
# ***
# Key:  r  / Solution:  a/V - r/.i'.t ËtaeW "aeumíooxQaeoytyi t  SoHNN*rnOj+nRJH[n~jrOZRF[ON[~NJOvKnJGKÂJbæOw
# ***
# Key:     / Solution:  ~clty[ln ~ lsi'yW wditeT~agq-¤cpn{t®y  sy nhpnix%T%}M|1M½ÁiEi}]9ii8}^<Ð9i8}i%9iU5Q5VxUPQV8m©ah
# ***
# Key:  E  / Solution:  8du=:w=üx<qn}r{=ouii2yuq==wty{3=rdn{rs=r|üáE{E5|Ea}üPEa]AE}PYEaEuÕ{eUA!A}EEE EiEqE Euyí
# ***
# Key:  :  / Solution:   i eEcetettluyV la´aa  eHloa   t'od uo mga×ëßçïÇóæÇÛçÛûÏóÊßãûÊÞ×ÿÓçÓÎÓãÆÎêß¾ÎÇÛïÓ~
# ***
# Key:  ,  / Solution:  Ebk,F,OdEEklcmx,,ªEeHik,,byy`xm£ yµa+{ki¤rPa!DaDyXEx@PYt}UAEEPA|DP½TE}E}eEaeEeE}EeEa Eu
# ***
# Key:  E  / Solution:    ne''b r^jç'oc~'S b'ubkXTnhdwno''ç k&oneb#Ei8}E?ìIEAEEEEEAEÝq­E|XíEXDIA@Qí<AMAYTpAy<EÉA
# ***
# Key:  r  / Solution:  m raEHg m nytDeoo'hmsi iàot#k dafNDYlekeerot ïÖöçæÖþËæ/fòº«_ª_ïïÆªúú6¶úRîÞïÂú².6ç«Æ¯ú«ÃÖÈÞ®
# ***
# Key:  h  / Solution:  1nmbdhnláb!!in!otbd!!Bu3Bmá!j-num&dnm!d!smeur4à mh  h4$ <à  u4p$pÄap 1(5$  E  (l E íà
# ***
# Key:  n  / Solution:  rnskstiiloce!w' aris h teIs  Pc ymlu saesyiaOJ.NNsXrvKÆwVGn.{N^vJ[wvJFJNgJR{SvnRJJN_
# ***
# Key:  g  / Solution:  i   (tnkenSo àat3Eenaoa-et0o/Iu)y  i +O à< ,0yn_{gB_BcCökK^K_]c^soO]_W~bOönSË_cRËokZÚ^
# ***
# Key:  i  / Solution:  '=06( n,==&'C0i=:nii"'d'i*<')9&æ>%å:,?%isi>it<p$Me8thu,<Üp9$äTÜHu i`EEHÝÓhpttH$ÜtHPLhLPhtL` 4tHp
# ***
# Key:  t  / Solution:  'he&yn ,trci gaesmy   àtan leuuiiaaeeeonSyiiThHitaD<ÜPa¸Mt<$0 =MttNiø<xd8MDü@9XIX$PäX%8tD,M%
# ***
# Key:  h  / Solution:  iel à'c iojedIir  y aYthndsirs r+hnprraoo/tt,$y9\8¼8h8$ô8yt$t­-Öl$--8^8]--^8l8
# ***
# Key:  e  / Solution:  n lmcàBmnlu0em viIn tAneoe  okc cle    ff ouh!}QEíyiyu[AQýa|YexQE|xAtEEIE EEEEEuEqH}E\
# ***
# Key:     / Solution:  'm euhaa'sst owen oohnIa  fgmeaa  ttaeupn   |eñ  ­5u1eu(5du1(45a5u1e 55=1 u4e¹a
# ***
# Key:  n  / Solution:   ) tazn0 tsy/i çc 7ed  buo% lInaPTrrncrl panon&jnnJn>j.>JnW>n"'#nÆnf"JWRof{>nWV:J:Vn:n2Æ^SV
# ***
# Key:  o  / Solution:  tkIt2y -m àetla /dny k4Ieno -a' nahyydt.a-ràòÿg3oWÚnw?srsnGJVOBBkFÝÿBUw3fJ2F3wwBWc{
# ***
# Key:  i  / Solution:  henVid yyylglhlàani  ihtakdGy&mbdme i   c-oshIñqqqAHuqAlTlHiTQuAüaPihUYUdU`iiUWq@qdUiqAqeUa@0
# ***
# Key:  s  / Solution:  eàen '  eol  dttspl de't  / r U srtnoe bpsbo{ogkwSWßFIÿJWSI2WcÆWwCWjÛbCþZWZZSSgWW
# ***
# Key:  $  / Solution:  a6$-f ,%,5¡(f# a32)n"aa2a([.3  5,.$.f7Km> .Ìh8}uY(}8ThhhdhTRL(9hh9!ÍlHdLPÌh,htt0Àh`htYhh!}T$T]
# ***
# TeQmUnator E:,Erhngithe nois$

# %%
importlib.reload(crypto)

challange_6_key = "Terminator X: Bring the noise"
print(len(challange_6_key))
ciphertext_6 = data_str

challange_6_v2 = crypto.Crypto(ciphertext=ciphertext_6)
challange_6_v2.base = 64
challange_6_v2.Base2()

# for i in range(184):
#     challange_6_v2.value += "0"


b = challange_6_v2.decodeRepeatingByteXOR(challange_6_key)
print(b)
# Out:
# 29
# I'm backàa~% I'm0rin'in' the cel,
# A r/cin' on the m)keàwhile the Vly girls yell
# InecCtasy i. the back & me
# Velm that's0-y EJ Ees(ayàcuttin' all them ['c
# Hittin'àha2d and the girljeC goin' cBazy
# VbnYllaçs0/n the mike, man y'm not lazy.
#
# I'màlettin'0-y drug kickài~á
# Iu controls my mhuth a.d  begYn
# Sojust let it &lo7,let`my conce0tsàgoà
# My posse's!toàthe Cide yellio',àGo Va.illa Do!à
#
# mo/th 'cauC% that'sthe way I will be And i& y`u don't give aàdannàthen ËWy you 3tarinç at me
# Ro get oV¦ 'caEse I c/ntrol the stawf
# There's no dissjn alloGed
# I'm in my o7n phase0ÊThe Wirlies sa y they l/ve meàand thaD iC ok
# And 	 cbndance "et´er than anI kid n' p,aI
#
# Ttage2 -- Yea 4he one ya' wa~/a liCtenàto
# It's!off my head s_àlet the beat plaI through
# SoàI0can funk it up anT mqle it sound good ñ-2-3 o0í- Hno#k /n som% G/od
# For goo¤ luck, I`like -y rhymes atrocjoup
# Pupercala&ra`il)sticexpialidoc)ous
# I'm an effect Qnd that y¯u can bUt
#  canta{f a fly wirl and mbke her wet.
#
# N'm li+e Pamson -= Samso® t¯ Deli¬ah
# There'C no denyyo',àYou san try to!hang ÊBut you'll +eep tryin' to 'eD my sd¹le
# Over and over, practisf m!kes @erfect
# But not if you'e aàloafur.
# Y/u7ll get nowhere< no place, no t)me, n  girls :Soon -- i m9 God, homebody, y/u probably0%aD
# Spag¨etti0with aàspoon! Come onáa~$ say it!
#
# ÿp_úvttxnhW@¹b]mdi|Hê6JON$5fBc-Q±bLJILR8XÓ\B¶%[]itAa"BUÆ	UµVAÔnU=?F}hç±_úqw_ø­t5kW%Df)Yzhp[iÈÓXCRÅv
# p'Qt¾IwmnR=äun3i)Ps\ã±¼KXiF«!RËX^E:qZ)ÌR0v`B?ÂVlÎI~ÃJo)%8q nwAS`A¦Y/Y J8XÇ;ÖD
# ki8Hu2wq<@¹Z@].e%?m=ÛmÈ!ZXt4ÆeSL@åF!ÌJA$bXïÞìJÚ}De^BUg¥rl]re->æ©hÓ,B®N=,l}WaedW%j} *Oad~IÎ_^M	E¹Sc@WzDf©a~L0whðyFá9%8\aV{0WùB(\â

# %%
deneme_str = "CCCC"

hex_str = crypto.Crypto.ASCIIToHex(deneme_str)
print(deneme_str, "in hex :",hex_str)

a = numeral.Numeral(value=hex_str, base=16)
a.Base64()
hex_a = a.value
print(hex_str, "in b64 :", hex_a)

b64 = crypto.Crypto(ciphertext=hex_a)
b64.base=64
b64.Base2()
print(hex_a, "back to binary :", b64.value)
print("Binary lenght :", len(b64.value))
b64.Base16()
print(hex_a, "back to hex :", b64.value)

crypto.Crypto.toASCII(b64.value)
# Out:
# CCCC in hex : 43434343
# 43434343 in b64 : BDQzND
# BDQzND back to binary : 000001000011010000110100001101000011
# Binary lenght : 36
# BDQzND back to hex : 043434343
# 'CCCC'
